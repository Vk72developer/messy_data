# %% [markdown]
# Data Collection and Inspection

# %%
import numpy as np 
import pandas as pd 

df = pd.read_csv("messy_customer_sales_data.csv") 
df
# Out:
#       Customer_ID               Name  ... Phone_Number Country
# 0        CUST4371        Paul Wilson  ...   2131107701   India
# 1        CUST5957       Jason Thomas  ...   1080761560   india
# 2        CUST3754  Brittney Martinez  ...   8981006345   India
# 3        CUST2934      Brenda Pierce  ...   8228064204   india
# 4        CUST5683    Matthew Carroll  ...   2665569480   India
# ...           ...                ...  ...          ...     ...
# 10195   CUST10767       Robert Lewis  ...   5004696571   InDia
# 10196         NaN        Diane Evans  ...   5200349941     IND
# 10197    CUST6315    Joshua Martinez  ...   8147428496   India
# 10198    CUST4812       Sarah Miller  ...   2987564247   InDia
# 10199    CUST6588       David Potter  ...   1926206725   India
#
# [10200 rows x 12 columns]

# %%
df.describe().round()
# Out:
#        Purchase_Amount  Feedback_Score  Phone_Number
# count           9179.0          9177.0  1.020000e+04
# mean           29090.0             5.0  4.979974e+09
# std           208697.0             3.0  2.902593e+09
# min             -500.0             1.0  9.208990e+05
# 25%            12295.0             3.0  2.449157e+09
# 50%            24330.0             5.0  4.988639e+09
# 75%            37130.0             8.0  7.510448e+09
# max          9999999.0            10.0  9.994402e+09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10200 entries, 0 to 10199
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_ID         9177 non-null   object
#  1   Name                10200 non-null  object
#  2   Gender              9174 non-null   object
#  3   Age                 9249 non-null   object
#  4   City                9184 non-null   object
#  5   Signup_Date         10200 non-null  object
#  6   Last_Purchase_Date  9188 non-null   object
#  7   Purchase_Amount     9179 non-null   float64
#  8   Feedback_Score      9177 non-null   float64
#  9   Email               10200 non-null  object
#  10  Phone_Number        10200 non-null  int64
#  11  Country             9468 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 956.4+ KB

# %%
df.isnull().sum()
# Out:
# Customer_ID           1023
# Name                     0
# Gender                1026
# Age                    951
# City                  1016
# Signup_Date              0
# Last_Purchase_Date    1012
# Purchase_Amount       1021
# Feedback_Score        1023
# Email                    0
# Phone_Number             0
# Country                732
# dtype: int64

# %%
df.isnull().sum()/len(df) * 100
# Out:
# Customer_ID           10.029412
# Name                   0.000000
# Gender                10.058824
# Age                    9.323529
# City                   9.960784
# Signup_Date            0.000000
# Last_Purchase_Date     9.921569
# Purchase_Amount       10.009804
# Feedback_Score        10.029412
# Email                  0.000000
# Phone_Number           0.000000
# Country                7.176471
# dtype: float64

# %%
df.shape
# Out:
# (10200, 12)

# %%
df.dropna().shape
# Out:
# (4528, 12)

# %%
df[df.duplicated()]
# Out:
#       Customer_ID               Name  ... Phone_Number Country
# 2032     CUST2755     Casey Campbell  ...   3844741384   India
# 3191          NaN   Travis Schneider  ...   7623118785   India
# 4312     CUST8305       Stanley Cain  ...   4889366037   India
# 5611     CUST6288       Jonathon Kim  ...   5266662560   India
# 5680     CUST2695        Lisa Durham  ...   2235480149   India
# 5899     CUST8841        Amanda Hill  ...   3466026146   India
# 6070    CUST10780        Emily Smith  ...   3032282870   India
# 6240     CUST9745      David Morales  ...   9436163110   India
# 6425     CUST4631       George Villa  ...   8869465862   India
# 6498     CUST1711  Stephanie Elliott  ...   3270872546     NaN
# 7118     CUST9380        Paul Wilson  ...   6835989909   India
# 8392     CUST1436     Ralph Anderson  ...   3739220307   India
# 9155    CUST10040        Mark Taylor  ...   9898365939   India
# 9960     CUST6220     John Rodriguez  ...   7462990833   India
# 10140    CUST4367      Amber Kennedy  ...   5600790669   India
#
# [15 rows x 12 columns]

# %%
df['Customer_ID'].value_counts().head(10)
# Out:
# Customer_ID
# CUST3344     2
# CUST4893     2
# CUST7000     2
# CUST10824    2
# CUST2695     2
# CUST4390     2
# CUST4186     2
# CUST2242     2
# CUST8746     2
# CUST1299     2
# Name: count, dtype: int64

# %%
df[df['Customer_ID'] == 'CUST3374']
# Out:
#      Customer_ID             Name  ... Phone_Number Country
# 2914    CUST3374  Timothy Wallace  ...   9687701793   India
# 3047    CUST3374  Timothy Wallace  ...   9687701793   India
#
# [2 rows x 12 columns]

# %%
for  col in df.columns:
    if df[col].nunique() < 20: 
        print(df[col].value_counts())
        print('-'*50)
# Out:
# Gender
# f         1184
# M         1171
# m         1163
# F         1157
# MALE      1131
# female    1128
# male      1121
# FEMALE    1119
# Name: count, dtype: int64
# --------------------------------------------------
# City
# Kolkata       820
# Mumbai        812
# Chennai       784
# Bangalore     773
# Hyderabad     770
# Delhi         763
# CHENNAI       404
# KOLKATA       395
# MUMBAI        393
# hyderabad     384
# bangalore     383
# DELHI         378
# delhi         369
# BANGALORE     363
# HYDERABAD     360
# mumbai        352
# chennai       343
# kolkata       338
# Name: count, dtype: int64
# --------------------------------------------------
# Feedback_Score
# 2.0     952
# 4.0     947
# 7.0     938
# 6.0     927
# 3.0     913
# 8.0     912
# 1.0     907
# 9.0     903
# 10.0    901
# 5.0     877
# Name: count, dtype: int64
# --------------------------------------------------
# Country
# India    7132
# IND       793
# india     772
# InDia     771
# Name: count, dtype: int64
# --------------------------------------------------

# %% [markdown]
# Handling Missing Data

# %%
df.dropna(subset=['Customer_ID'], inplace=True)

# %%
df.isnull().sum()
# Out:
# Customer_ID             0
# Name                    0
# Gender                934
# Age                   859
# City                  918
# Signup_Date             0
# Last_Purchase_Date    914
# Purchase_Amount       927
# Feedback_Score        905
# Email                   0
# Phone_Number            0
# Country               664
# dtype: int64

# %%
df
# Out:
#       Customer_ID               Name  ... Phone_Number Country
# 0        CUST4371        Paul Wilson  ...   2131107701   India
# 1        CUST5957       Jason Thomas  ...   1080761560   india
# 2        CUST3754  Brittney Martinez  ...   8981006345   India
# 3        CUST2934      Brenda Pierce  ...   8228064204   india
# 4        CUST5683    Matthew Carroll  ...   2665569480   India
# ...           ...                ...  ...          ...     ...
# 10194    CUST6146      Cody Thompson  ...   6380823112   India
# 10195   CUST10767       Robert Lewis  ...   5004696571   InDia
# 10197    CUST6315    Joshua Martinez  ...   8147428496   India
# 10198    CUST4812       Sarah Miller  ...   2987564247   InDia
# 10199    CUST6588       David Potter  ...   1926206725   India
#
# [9177 rows x 12 columns]

# %%
df['Age'].unique()
# Out:
# array(['52.0', '51.0 years', '62.0', '40.0', '41.0', nan, '18.0',
#        '43.0 years', '40.0 years', '26.0', '32.0', '22.0', '59.0', '65.0',
#        '61.0', '31.0', '54.0 years', '55.0', '69.0', '61.0 years', '24.0',
#        '63.0', '19.0', '50.0', '56.0', '36.0', '68.0', '43.0', '38.0',
#        '27.0', '57.0 years', '23.0', '25.0', '66.0', '28.0', '30.0',
#        '46.0', '48.0', '20.0', '37.0', '67.0', '51.0', '35.0', '58.0',
#        '29.0', 'nan years', '39.0', '49.0', '47.0', '42.0', '44.0',
#        '64.0', '53.0', '60.0', '59.0 years', '45.0', '21.0', '34.0',
#        '54.0', '48.0 years', '46.0 years', '33.0', '57.0', '30.0 years',
#        '58.0 years', '35.0 years', '34.0 years', '69.0 years', '250',
#        '19.0 years', '27.0 years', '53.0 years', '65.0 years',
#        '66.0 years', '44.0 years', '49.0 years', '25.0 years',
#        '23.0 years', '62.0 years', '41.0 years', '33.0 years',
#        '28.0 years', '22.0 years', '20.0 years', '42.0 years',
#        '45.0 years', '3', '63.0 years', '37.0 years', '38.0 years',
#        '55.0 years', '18.0 years', '36.0 years', '67.0 years',
#        '29.0 years', '39.0 years', '31.0 years', '47.0 years',
#        '52.0 years', '-10', '60.0 years', '24.0 years', '26.0 years',
#        '21.0 years', '64.0 years', '50.0 years', '68.0 years',
#        '32.0 years', '56.0 years'], dtype=object)

# %%
import re
def extract_age(age): 
    age_num = re.findall('[0-9]+', str(age)) 
    if len(age_num) > 0: 
        return age_num[0] 
    else:
        return age

df['Age'] = df['Age'].apply(lambda x : extract_age(x))

# %%
df
# Out:
#       Customer_ID               Name  ... Phone_Number Country
# 0        CUST4371        Paul Wilson  ...   2131107701   India
# 1        CUST5957       Jason Thomas  ...   1080761560   india
# 2        CUST3754  Brittney Martinez  ...   8981006345   India
# 3        CUST2934      Brenda Pierce  ...   8228064204   india
# 4        CUST5683    Matthew Carroll  ...   2665569480   India
# ...           ...                ...  ...          ...     ...
# 10194    CUST6146      Cody Thompson  ...   6380823112   India
# 10195   CUST10767       Robert Lewis  ...   5004696571   InDia
# 10197    CUST6315    Joshua Martinez  ...   8147428496   India
# 10198    CUST4812       Sarah Miller  ...   2987564247   InDia
# 10199    CUST6588       David Potter  ...   1926206725   India
#
# [9177 rows x 12 columns]

# %%
df['Age'].unique()
# Out:
# array(['52', '51', '62', '40', '41', nan, '18', '43', '26', '32', '22',
#        '59', '65', '61', '31', '54', '55', '69', '24', '63', '19', '50',
#        '56', '36', '68', '38', '27', '57', '23', '25', '66', '28', '30',
#        '46', '48', '20', '37', '67', '35', '58', '29', 'nan years', '39',
#        '49', '47', '42', '44', '64', '53', '60', '45', '21', '34', '33',
#        '250', '3', '10'], dtype=object)

# %%
df_age = df[df['Age'] != 'nan years']['Age']

# %%
age_median = int(df_age.dropna().astype('int64').median())

# %%
age_median
# Out:
# 43

# %%
df.replace('nan years', age_median, inplace=True)

# %%
df['Age'].fillna(age_median, inplace=True)

# %%
df['Age'].unique()
# Out:
# array(['52', '51', '62', '40', '41', 43, '18', '43', '26', '32', '22',
#        '59', '65', '61', '31', '54', '55', '69', '24', '63', '19', '50',
#        '56', '36', '68', '38', '27', '57', '23', '25', '66', '28', '30',
#        '46', '48', '20', '37', '67', '35', '58', '29', '39', '49', '47',
#        '42', '44', '64', '53', '60', '45', '21', '34', '33', '250', '3',
#        '10'], dtype=object)

# %%
df['Purchase_Amount'].unique()
# Out:
# array([26944., 44152., 31745., ..., 24167., 43832., 18827.])

# %%
df.isnull().sum()
# Out:
# Customer_ID           0
# Name                  0
# Gender                0
# Age                   0
# City                  0
# Signup_Date           0
# Last_Purchase_Date    0
# Purchase_Amount       0
# Feedback_Score        0
# Email                 0
# Phone_Number          0
# Country               0
# dtype: int64

# %%
df['Purchase_Amount'].fillna(df['Purchase_Amount'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Customer_ID           0
# Name                  0
# Gender                0
# Age                   0
# City                  0
# Signup_Date           0
# Last_Purchase_Date    0
# Purchase_Amount       0
# Feedback_Score        0
# Email                 0
# Phone_Number          0
# Country               0
# dtype: int64

# %%
df['Feedback_Score'].fillna(df['Feedback_Score'].mode()[0], inplace =True)

# %%
df.isnull().sum()
# Out:
# Customer_ID             0
# Name                    0
# Gender                  0
# Age                     0
# City                    0
# Signup_Date             0
# Last_Purchase_Date    914
# Purchase_Amount         0
# Feedback_Score          0
# Email                   0
# Phone_Number            0
# Country                 0
# dtype: int64

# %%
for col in ['Gender', 'City', 'Country']: 
    df[col].fillna(df[col].mode()[0], inplace=True)

# %%
df['Last_Purchase_Date'].ffill(inplace=True)

# %%
df.isnull().sum()
# Out:
# Customer_ID           0
# Name                  0
# Gender                0
# Age                   0
# City                  0
# Signup_Date           0
# Last_Purchase_Date    0
# Purchase_Amount       0
# Feedback_Score        0
# Email                 0
# Phone_Number          0
# Country               0
# dtype: int64

# %% [markdown]
# Fixing Inconsistent Formatting

# %%
df['Gender'].unique()
# Out:
# array(['m ', 'M', 'F', 'FEMALE', 'f ', 'male', 'MALE', 'female'],
#       dtype=object)

# %%
df['Gender'] = df['Gender'].str.lower().str.strip()

# %%
df['Gender'].replace({'m': 'male', 'f': 'female'}, inplace=True)

# %%
df['Gender'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['City'] = df['City'].str.strip().str.lower()

# %%
df['City'].unique()
# Out:
# array(['kolkata', 'hyderabad', 'chennai', 'bangalore', 'mumbai', 'delhi'],
#       dtype=object)

# %%
df['Country'].unique()
# Out:
# array(['India', 'india', 'InDia', 'IND'], dtype=object)

# %%
df['Country']  = df['Country'].str.lower()

# %%
df['Country'].replace({'ind': 'india'}, inplace=True)

# %%
df['Country'].unique()
# Out:
# array(['india'], dtype=object)

# %% [markdown]
# Handling Duplicate Data

# %%
df[df.duplicated()]
# Out:
#       Customer_ID               Name  ... Phone_Number Country
# 1956     CUST8512    Matthew Roberts  ...   1319901506   india
# 1974     CUST6647      Julie Padilla  ...   2514229747   india
# 2032     CUST2755     Casey Campbell  ...   3844741384   india
# 2110     CUST7014  Phillip Rodriguez  ...   1392088762   india
# 2381     CUST5472      Linda Patrick  ...   6356542249   india
# ...           ...                ...  ...          ...     ...
# 10140    CUST4367      Amber Kennedy  ...   5600790669   india
# 10158    CUST1317        Ashley Hall  ...   6840741983   india
# 10182    CUST1740          Eric Rush  ...   3093645885   india
# 10185    CUST7439      Kara Gallegos  ...    923465413   india
# 10199    CUST6588       David Potter  ...   1926206725   india
#
# [163 rows x 12 columns]

# %%
df[df.duplicated()].shape
# Out:
# (163, 12)

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()].shape
# Out:
# (0, 12)

# %%
df.drop_duplicates(subset=['Customer_ID'], keep='first', inplace=True)

# %%
df.shape
# Out:
# (9000, 12)

# %% [markdown]
# Correcting Data Types

# %%
df['Age'] = df['Age'].astype('int64')

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Name', 'Gender', 'Age', 'City', 'Signup_Date',
#        'Last_Purchase_Date', 'Purchase_Amount', 'Feedback_Score', 'Email',
#        'Phone_Number', 'Country'],
#       dtype='object')

# %%
df['Signup_Date'] = pd.to_datetime(df['Signup_Date'])

# %%
df['Last_Purchase_Date'] = pd.to_datetime(df['Last_Purchase_Date'])

# %%
df.dtypes
# Out:
# Customer_ID                   object
# Name                          object
# Gender                        object
# Age                            int64
# City                          object
# Signup_Date           datetime64[ns]
# Last_Purchase_Date    datetime64[ns]
# Purchase_Amount              float64
# Feedback_Score               float64
# Email                         object
# Phone_Number                   int64
# Country                       object
# dtype: object

# %% [markdown]
# Handling Outliers

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 

cols = ['Age', 'Purchase_Amount', 'Feedback_Score']

plt.figure(figsize=(15, 5))

for i, col in enumerate(cols, 1): 
    plt.subplot(1, 3, i)
    sns.boxplot(y = df[col], color='skyblue', width=0.3) 
    plt.title(f'Boxplot of {col}', fontsize=12)
    plt.ylabel(' ')
    plt.grid(axis='y', linestyle='--', alpha=0.6) 

plt.tight_layout()
plt.show()

# %%
from scipy import stats

# %%
import numpy as np 
z_scores = np.abs(stats.zscore(df[['Age', 'Purchase_Amount']]))

# %%
df_clean =  df[~(z_scores > 3).any(axis = 1)]

# %%
df_clean.shape
# Out:
# (8989, 12)

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 

cols = ['Age', 'Purchase_Amount', 'Feedback_Score']

plt.figure(figsize=(15, 5))

for i, col in enumerate(cols, 1): 
    plt.subplot(1, 3, i)
    sns.boxplot(y = df_clean[col], color='skyblue', width=0.3) 
    plt.title(f'Boxplot of {col}', fontsize=12)
    plt.ylabel(' ')
    plt.grid(axis='y', linestyle='--', alpha=0.6) 

plt.tight_layout()
plt.show()
